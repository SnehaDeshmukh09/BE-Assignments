# %%
import pandas as pd

# %%
ds = pd.read_csv('/content/car_price_dataset.csv')

# %%
ds
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         10000 non-null  object
#  1   Model         10000 non-null  object
#  2   Year          10000 non-null  int64
#  3   Engine_Size   10000 non-null  float64
#  4   Fuel_Type     10000 non-null  object
#  5   Transmission  10000 non-null  object
#  6   Mileage       10000 non-null  int64
#  7   Doors         10000 non-null  int64
#  8   Owner_Count   10000 non-null  int64
#  9   Price         10000 non-null  int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 781.4+ KB

# %%
ds.brand
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-907ae6b3a799> in <cell line: 0>()
# ----> 1 ds.brand
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'brand'

# %%
ds.Brand
# Out:
# 0              Kia
# 1        Chevrolet
# 2         Mercedes
# 3             Audi
# 4       Volkswagen
#            ...
# 9995           Kia
# 9996     Chevrolet
# 9997           BMW
# 9998          Ford
# 9999    Volkswagen
# Name: Brand, Length: 10000, dtype: object

# %%
ds['Brand']
# Out:
# 0              Kia
# 1        Chevrolet
# 2         Mercedes
# 3             Audi
# 4       Volkswagen
#            ...
# 9995           Kia
# 9996     Chevrolet
# 9997           BMW
# 9998          Ford
# 9999    Volkswagen
# Name: Brand, Length: 10000, dtype: object

# %%
ds[['Brand','Model','Year','Engine_Size']]   #Feature Engineering
# Out:
#            Brand     Model  Year  Engine_Size
# 0            Kia       Rio  2020          4.2
# 1      Chevrolet    Malibu  2012          2.0
# 2       Mercedes       GLA  2020          4.2
# 3           Audi        Q5  2023          2.0
# 4     Volkswagen      Golf  2003          2.6
# ...          ...       ...   ...          ...
# 9995         Kia    Optima  2004          3.7
# 9996   Chevrolet    Impala  2002          1.4
# 9997         BMW  3 Series  2010          3.0
# 9998        Ford  Explorer  2002          1.4
# 9999  Volkswagen    Tiguan  2001          2.1
#
# [10000 rows x 4 columns]

# %%
ds.columns
# Out:
# Index(['Brand', 'Model', 'Year', 'Engine_Size', 'Fuel_Type', 'Transmission',
#        'Mileage', 'Doors', 'Owner_Count', 'Price'],
#       dtype='object')

# %%
ds.describe()     #Statistical Summary
# Out:
#                Year   Engine_Size        Mileage         Doors   Owner_Count  \
# count  10000.000000  10000.000000   10000.000000  10000.000000  10000.000000
# mean    2011.543700      3.000560  149239.111800      3.497100      2.991100
# std        6.897699      1.149324   86322.348957      1.110097      1.422682
# min     2000.000000      1.000000      25.000000      2.000000      1.000000
# 25%     2006.000000      2.000000   74649.250000      3.000000      2.000000
# 50%     2012.000000      3.000000  149587.000000      3.000000      3.000000
# 75%     2017.000000      4.000000  223577.500000      4.000000      4.000000
# max     2023.000000      5.000000  299947.000000      5.000000      5.000000
#
#              Price
# count  10000.00000
# mean    8852.96440
# std     3112.59681
# min     2000.00000
# 25%     6646.00000
# 50%     8858.50000
# 75%    11086.50000
# max    18301.00000

# %%
ds[ds['Fuel_Type']=='Hybrid']      #show only hybrid cars
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 8            Kia  Sportage  2014          2.6    Hybrid          Manual
# 10           BMW  5 Series  2013          1.3    Hybrid       Automatic
# 11    Volkswagen      Golf  2009          4.5    Hybrid          Manual
# ...          ...       ...   ...          ...       ...             ...
# 9984  Volkswagen    Passat  2023          3.0    Hybrid          Manual
# 9985        Audi        A4  2003          1.4    Hybrid       Automatic
# 9992         BMW  5 Series  2016          1.2    Hybrid       Automatic
# 9993       Honda    Accord  2019          4.7    Hybrid  Semi-Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
#
#       Mileage  Doors  Owner_Count  Price
# 1        5356      2            3  12092
# ...

# %%
#How many Honda cars do we have?

ds[ds['Brand']=='Honda']
# Out:
#       Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 6     Honda   Civic  2010          3.4  Electric       Automatic   139584
# 12    Honda    CR-V  2007          4.8    Hybrid       Automatic   132875
# 42    Honda   Civic  2000          3.9    Hybrid          Manual    56020
# 53    Honda   Civic  2015          2.6  Electric  Semi-Automatic    66777
# 59    Honda   Civic  2005          2.4    Petrol       Automatic    60316
# ...     ...     ...   ...          ...       ...             ...      ...
# 9944  Honda   Civic  2021          2.6  Electric  Semi-Automatic   212430
# 9945  Honda  Accord  2000          2.8    Petrol       Automatic   124129
# 9980  Honda    CR-V  2012          1.5    Petrol          Manual    37233
# 9993  Honda  Accord  2019          4.7    Hybrid  Semi-Automatic   155874
# 9994  Honda   Civic  2016          2.9    Petrol          Manual   255889
#
#       Doors  Owner_Count  Price
# 6         3            1  11208
# ...

# %%
ds[ds['Brand']=="BMW"]
# Out:
#      Brand     Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 10     BMW  5 Series  2013          1.3    Hybrid       Automatic   296824
# 27     BMW  3 Series  2017          2.3  Electric  Semi-Automatic   142701
# 28     BMW  3 Series  2020          4.7  Electric  Semi-Automatic   210767
# 41     BMW  5 Series  2007          4.9    Petrol          Manual   120491
# 55     BMW  3 Series  2011          2.9  Electric  Semi-Automatic   281020
# ...    ...       ...   ...          ...       ...             ...      ...
# 9977   BMW        X5  2002          4.0    Hybrid  Semi-Automatic   286275
# 9987   BMW  5 Series  2004          1.3    Diesel          Manual    19392
# 9988   BMW  3 Series  2010          3.0    Diesel          Manual   105615
# 9992   BMW  5 Series  2016          1.2    Hybrid       Automatic    13386
# 9997   BMW  3 Series  2010          3.0    Petrol       Automatic    86664
#
#       Doors  Owner_Count  Price
# 10        2            3   5863
# ...

# %%
ds[ds['Brand']!= 'BMW']
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9994       Honda     Civic  2016          2.9    Petrol          Manual
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
ds['Brand'].unique()
# Out:
# array(['Kia', 'Chevrolet', 'Mercedes', 'Audi', 'Volkswagen', 'Toyota',
#        'Honda', 'BMW', 'Hyundai', 'Ford'], dtype=object)

# %%
ds[ds['Engine_Size']>2]
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# 5         Toyota     Camry  2007          2.7    Petrol       Automatic
# 6          Honda     Civic  2010          3.4  Electric       Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9993       Honda    Accord  2019          4.7    Hybrid  Semi-Automatic
# 9994       Honda     Civic  2016          2.9    Petrol          Manual
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
ds.head(5)
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
ds.tail(5)
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 9995     5794      2            4   8884
# 9996   168000      2            1   6240
# 9997    86664      5            1   9866
# 9998   225772      4            1   4084
# 9999   157882      3            3   3342

# %%
ds.sample(5)
# Out:
#           Brand     Model  Year  Engine_Size Fuel_Type Transmission  Mileage  \
# 4807     Toyota      RAV4  2022          4.6    Hybrid       Manual   142869
# 2132      Honda      CR-V  2021          1.3    Hybrid    Automatic   295825
# 747         BMW  3 Series  2020          3.1    Hybrid    Automatic   156278
# 1192  Chevrolet    Impala  2017          2.4    Hybrid    Automatic   175959
# 2049      Honda     Civic  2018          1.7  Electric       Manual   286878
#
#       Doors  Owner_Count  Price
# 4807      2            2  13442
# 2132      4            5   8283
# 747       2            5  12574
# 1192      4            3  10580
# 2049      2            1   7462
